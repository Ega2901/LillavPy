# %% [markdown]
# ![image.png](attachment:78070cf8-32cb-4821-b42b-360b42ba1df3.png)

# %%
elements = 'H He Be Li B C N O F Ne Na Mg Al Si P S Cl Ar'
el = elements.split()

with open('elements.txt', 'w') as f:
  for i in range(1, len(el) + 1):
    f.write(f'{i}\t{el[i-1]}\n')
