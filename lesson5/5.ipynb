# %% [markdown]
# ![image.png](attachment:99b28aff-1343-4219-81b6-6fc1c0495cea.png)

# %%
A = [1,1,1,2]

def calc_A(k):
    if k < 4:
        return A[k]
    
    for n in range(3,k):
        sum1 = sum(A[i] * A[j] * A[n-i-j] for i in range(n+1) for j in range(n-i+1))
        sum2 = sum(A[i] * A[n-2*i] for i in range((n//2)+1))
        sum3 = A[n//3]
        
        A.append((sum1 + sum2*3 + sum3*2) // 6)
    
    return A[k]

print(calc_A(int(input("Введите k:\n"))))
# Out:
# Введите k:
#  10
# 507

# %%
def calc_P(A, k):
    for n in range(3,k):
