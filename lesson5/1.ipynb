# %% [markdown]
# ![image.png](attachment:e4581883-baab-470b-883a-86d37cad8893.png)

# %%
T3_CO2, p3_CO2 = 216.58, 5.185e5
DfusH_CO2 = 9.019
DfusS_CO2 = 40
DvapH_CO2 = 15.326
DvapS_CO2 = 70.8
Т3_Н2O, р3_Н2O = 273.16, 611.73
DfusH_H2O = 6.01
DfusS_H2O = 22.0
DvapH_H2O = 40.68
DvapS_H2O = 118.89

print(f"{'':<22}{'CO2':<15}{'H2O':<10}")
print(f"{'-'*42}")

print(f"p3{'':<5}/Pa{'':<10}{p3_CO2:<16}{р3_Н2O:<10}")
print(f"T3{'':<5}/K{'':<11}{T3_CO2:<16}{Т3_Н2O:<10}")
print(f"DfusH{'':<2}/kJ.mol-1{'':<4}{DfusH_CO2:<16}{DfusH_H2O:<10}")
print(f"DfusS{'':<2}/J.K-1.mol-1{'':<1}{DfusS_CO2:<16}{DfusS_H2O:<10}")
print(f"DvapH{'':<2}/kJ.mol-1{'':<4}{DvapH_CO2:<16}{DvapH_H2O:<10}")
print(f"DvapS{'':<2}/J.K-1.mol-1{'':<1}{DvapS_CO2:<16}{DvapS_H2O:<10}")
# Out:
#                       CO2            H2O
# ------------------------------------------
# p3     /Pa          518500.0        611.73
# T3     /K           216.58          273.16
# DfusH  /kJ.mol-1    9.019           6.01
# DfusS  /J.K-1.mol-1 40              22.0
# DvapH  /kJ.mol-1    15.326          40.68
# DvapS  /J.K-1.mol-1 70.8            118.89

# %%
print("Hello {}, your balance is {}.".format("Adam", 230.2346))
# Out:
# Hello Adam, your balance is 230.2346.

# %% [markdown]
# ![image.png](attachment:5ffb8ebf-0662-4f9a-b7dd-62dfe25eb087.png)
